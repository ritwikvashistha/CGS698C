# %% [markdown]
# #                                         Assignment 1

# %% [markdown]
# **Q1 Consider the first example we did in class where we wanted to find the probability p(for Heads) of a coin. Reproduce what we discussed in class as follows:**
#
# *First construct a sampler with a known p value.  You will use this to generate data for your Bayesiananalysis for different values of p.

# %% [markdown]
# Importing Libraries and Constructing a Sampler

# %%
import matplotlib.pyplot  as plt
import numpy as np
from scipy.stats import beta
from matplotlib.figure import Figure
import pymc3 as pm
import arviz as az
from scipy.stats import beta
from scipy.stats import bernoulli
import warnings;
warnings.simplefilter(action="ignore", category=FutureWarning)

def sampler(p,trials):
    return np.random.binomial(n=1,p=p,size=trials)

# %% [markdown]
# * Using the following 4 priors i) non-informative ii) prior with a peak at p= 0.25 iii) prior with a peak at p= 0.5 and iv) prior with peak at p= 0.75 and the likelihood (you can use the one which was discussed in class) plot the posterior distribution as your generate data.  In particular show plots for what happensafter 1, 2, 3, 4 data points and after 1K and 4K data points.  You can use a β-distribution to create the peaked priors

# %% [markdown]
# FOR N=1

# %%
import warnings
warnings.filterwarnings('ignore')
x=np.arange(0.0,1,0.001)

def posterior(a,b,trials,p,z):   
 d1=sampler(p,trials)   
 with pm.Model() as model:
    theta=pm.Beta('theta',alpha= a,beta=b)
    y=pm.Binomial('y',n=trials,p=theta,observed=sum(d1))
    trace=pm.sample(1000,random_seed=123,cores=1)
    f=az.plot_posterior(trace, credible_interval=0.99)
    plt.title(z)
    plt.plot(x, beta.pdf(x,a=a,b=b),'--',label="Prior")
    plt.legend(loc="upper left")
    
z=['For Non-informative Prior ','For Prior with Peak at 0.25 ','For Prior with Peak at 0.5 ','For Prior with Peak at 0.75']      
n_trials=[1,2,3,4,1000,4000]
beta_parameters=[(1,1),(6,16),(7,7),(16,6)] 
    
for j,(a,b) in enumerate(beta_parameters):
    posterior(a,b,n_trials[0],0.5,z[j])
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# FOR N=2

# %%
for j,(a,b) in enumerate(beta_parameters):
    posterior(a,b,n_trials[1],0.5,z[j])
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# FOR N=3

# %%
for j,(a,b) in enumerate(beta_parameters):
    posterior(a,b,n_trials[2],0.5,z[j])
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# FOR N=4

# %%
for j,(a,b) in enumerate(beta_parameters):
    posterior(a,b,n_trials[3],0.5,z[j])
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# FOR N=1000

# %%
  for j,(a,b) in enumerate(beta_parameters):
    posterior(a,b,n_trials[4],0.5,z[j])
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# FOR N=4000

# %%
  for j,(a,b) in enumerate(beta_parameters):
    posterior(a,b,n_trials[5],0.5,z[j])
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# * Also, check what happens when you do the first 4 data items one-by-one versus after all four items are available - whether you get the same posterior

# %%
d1=sampler(0.5,4)
d1
# Out:
# array([1, 1, 1, 0])

# %%
with pm.Model() as model:
  theta=pm.Beta('theta',1,1)
  data=pm.Bernoulli('data',theta,observed=d1[0])
  trace=pm.sample(4000,cores=1)
  az.plot_posterior(trace)
with pm.Model() as model:
  theta=pm.Beta('theta',1+sum(d1[0:1]),2-sum(d1[0:1]))
  data=pm.Bernoulli('data',theta,observed=d1[1])
  trace=pm.sample(4000,cores=1)
  az.plot_posterior(trace)
    
with pm.Model() as model:
  theta=pm.Beta('theta',1+sum(d1[0:2]),3-sum(d1[0:2]))
  data=pm.Bernoulli('data',theta,observed=d1[2])
  trace=pm.sample(4000,cores=1)
  az.plot_posterior(trace)
with pm.Model() as model:
  theta=pm.Beta('theta',1+sum(d1[0:3]),4-sum(d1[0:3]))
  data=pm.Bernoulli('data',theta,observed=d1[3])
  trace=pm.sample(4000,cores=1)
  az.plot_posterior(trace,credible_interval=0.95)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5000' class='' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5000/5000 00:02<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %%
with pm.Model() as model:
  theta=pm.Beta('theta',1,1)
  data=pm.Binomial('data',n=4,p=theta,observed=sum(d1))
  trace=pm.sample(4000,cores=1)
  az.plot_posterior(trace,credible_interval=0.95)
  plt.legend(loc="upper left")
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5000' class='' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5000/5000 00:02<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# We see that Posterior distribution in both the cases are almost same.

# %% [markdown]
# **Q2.  Consider the height-weight correlation example.  Build a Bayesian model for the correlation by finding posteriors for β0,β1,σ as follows**

# %% [markdown]
# * First create a data generator by assuming reasonable values for the three parameters β0,β1,σ. To generatea data points first draw a height valueh∼N(μh,σh) (choose μh,σh suitably), then use the regression equation to generate a predicted value, say  ˆw, draw the sample data point using w∼N( ˆw,σ).

# %%
import matplotlib.pyplot  as plt
import numpy as np
from scipy.stats import beta
from matplotlib.figure import Figure
import pymc3 as pm
import arviz as az
from scipy.stats import uniform
from numpy.random import normal
import pandas as pd
from random import sample
from statistics import mean
from statistics import stdev
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

def data_gen(trials):
    beta_0=-310                    #TRUE VALUE
    beta_1=7                       #TRUE VALUE   
    sigma=10                       #TRUE VALUE 
    h=normal(65,7,trials)
    w=[]
    w1=[]
    for i in range(0,trials):
        w.append(normal(beta_0+beta_1*h[i],sigma,1))
        w1.append(w[i][0])
        
    return(h,w1)

# %% [markdown]
# * For two priors given below compute the posterior distributions for the three parameters for sample sizes of 10, 100 and 1000 and plot the distribution and the 95% HDI.The two priors are:  i) a non-informative prior (done in class) and ii) a more informed prior created bydrawing 10 data points using the generator in part (a) and then using N(μ′,σ′) as the prior where μ′,σ′are the sample mean and sample standard deviation of the ten-sized sample.

# %% [markdown]
# For Non Informative Prior

# %%
def posterior_0(h,w):   
 with pm.Model() as model:
    alpha=pm.Uniform('alpha',-500,500)
    beta=pm.Uniform('beta',-10,10)
    std=pm.Uniform('sd',0,100)
    w_pred = pm.Normal('y_pred', mu= alpha + beta*h, sd=std, observed=w)
    trace=pm.sample(2000,cores=1)
    az.plot_posterior(trace, credible_interval=0.95)

# %% [markdown]
# FOR N=10

# %%
h,w=data_gen(10)
posterior_0(h,w)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:14<00:00 Sampling chain 0, 23 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# FOR N=100

# %%
h,w=data_gen(100)
posterior_0(h,w)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:12<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# FOR N=1000

# %%
h,w=data_gen(1000)
posterior_0(h,w)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:12<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# For Informative Prior

# %%
def posterior_1(h,w,bo,b1,sigma):   
 with pm.Model() as model:
    alpha=pm.Normal('alpha',mu=bo,sd=150)
    beta=pm.Normal('beta',b1,150)
    std=pm.Normal('sd',sigma,150)
    w_pred = pm.Normal('y_pred', mu= alpha + beta*h, sd=std, observed=w)
    trace=pm.sample(4000,cores=1)
    az.plot_posterior(trace, credible_interval=0.95)

# %% [markdown]
# FOR N=100

# %%
h,w=data_gen(100)
sample_h=np.array(sample(list(h),10)).reshape((-1, 1))
sample_w=sample(list(w),10)

model = LinearRegression().fit(sample_h, sample_w)
bo=model.intercept_
b1=model.coef_[0]
w_predicted = model.predict(sample_h)
rms = mean_squared_error(sample_w, w_predicted, squared=False)
posterior_1(h,w,bo,b1,rms)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5000' class='' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5000/5000 00:17<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# FOR N=1000

# %%
h,w=data_gen(1000)
sample_h=np.array(sample(list(h),10)).reshape((-1, 1))
sample_w=sample(list(w),10)

model = LinearRegression().fit(sample_h, sample_w)
bo=model.intercept_
b1=model.coef_[0]
w_predicted = model.predict(sample_h)
rms = mean_squared_error(sample_w, w_predicted, squared=False)
posterior_1(h,w,bo,b1,rms)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5000' class='' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5000/5000 00:20<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...

# %% [markdown]
# Regression Coefficients

# %%
h,w=data_gen(1000)
sample_h=np.array(sample(list(h),10)).reshape((-1, 1))
sample_w=sample(list(w),10)

model = LinearRegression().fit(sample_h, sample_w)
bo=model.intercept_
b1=model.coef_[0]
w_predicted = model.predict(sample_h)
rms = mean_squared_error(sample_w, w_predicted, squared=False)
print(bo,b1,rms)
# Out:
# 60.73016406674651 1.326578088604772 49.44444477452185

# %% [markdown]
# **Note that, I had to take large Standard Deviation while specifying Prior Distribution in Informative Case because Regression Estimates based on 10 Samples were extremely poor and if i had taken a small standard deviation then the posterior distribution would have turned out to be poor as well.**
